# %%
barang = []

perintah = 0
while perintah != 'stop':
  print('''1.menambah
  2. menghapus
  3. mengubah
  4. menampilkan
  5. memeriksa barang
  6. mencari indeks''')
  perintah = input("masukkan perintah :")

  if perintah == '1' :
    namabarang = input("masukkan nama barang :")
    barang.append(namabarang)

  elif perintah == '2' :
    index =int(input("masukkan index yang akan di hapus :"))
    barang.pop(index)
  
  elif perintah == '3' :
    barang1 = int(input("masukkan index yang akan diubah :"))
    barang [barang1] = input("masukkan barang yang baru :")

  elif perintah == '4' :
    for i in barang :
      print(i)

  elif perintah == '5' :
    cari = input("masukkan nama barang yang dicari :")
    if cari in barang :
      print("barang di temukan")
    else :
      print("barang tidak ditemukan")

  elif perintah == '6' :
    cari =input("masukkan item yang dicari :")
    if cari in barang:
      print(barang.index(cari))
    else :
      print("item tidak ditemukan")


print(barang)
# Out:
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :hp
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :1
# masukkan nama barang :hp
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :4
# hp
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :1
# masukkan nama barang :buku
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :1
# masukkan nama barang :pulpen
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :4
# hp
# buku
# pulpen
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :2
# masukkan index yang akan di hapus :2
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :4
# hp
# buku
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :3
# masukkan index yang akan diubah :1
# masukkan barang yang baru :sandal
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :4
# hp
# sandal
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :5
# masukkan nama barang yang dicari :lemari
# barang tidak ditemukan
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :5
# masukkan nama barang yang dicari :hp
# barang di temukan
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
# masukkan perintah :6
# masukkan item yang dicari :sandal
# 1
# 1.menambah
#   2. menghapus
#   3. mengubah
#   4. menampilkan
#   5. memeriksa barang
#   6. mencari indeks
