# %%
barang = []

while True:
  print('''1. Menambah
2. Menghapus
3. Mengedit
4. Menampilkan
5. Memeriksa Barang
6. Mencari Index''')
  perintah = input("Masukkan Perintah: ")

  if perintah == '1':
    tmb = input("Masukkan Barang: ")
    barang.append(tmb)
  elif perintah == '2' :
    index =int(input("masukkan index yang akan di hapus :"))
    barang.pop(index)
  elif perintah == '3':
    edit = input("Masukkan Barang yang akan diedit: ")
    index = None
    for i in range(len(barang)):
      if barang [i] == edit:
        index = i

    if index == None:
      print("Barang tidak ditemukan.")
    else:
      barang [index] = input("Masukkan Barang yang Baru: ")
  elif perintah == '4':
    print(barang)
  
  elif perintah == '5' :
    cari = input("masukkan nama barang yang dicari :")
    if cari in barang :
      print("barang di temukan")
    else :
      print("barang tidak ditemukan")
      
  elif perintah == '6':
    cariz = input("Masukkan Barang yang akan dicari indexnya: ")
    index = None
    for i in range(len(barang)):
      if barang [i] == cariz:
        index = i

    if index == None:
      print("Barang tidak ditemukan.")
    else:
      print("{} ada pada index ke-{}". format(cariz, index))
  else:
    break



print("Program Berhenti. Selamat Tinggal")
# Out:
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 1
# Masukkan Barang: hp
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 1
# Masukkan Barang: buku
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 1
# Masukkan Barang: tas
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 4
# ['hp', 'buku', 'tas']
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 2
# masukkan index yang akan di hapus :2
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 4
# ['hp', 'buku']
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 3
# Masukkan Barang yang akan diedit: hp
# Masukkan Barang yang Baru: mobil
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 4
# ['mobil', 'buku']
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 5
# masukkan nama barang yang dicari :pulpen
# barang tidak ditemukan
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 5
# masukkan nama barang yang dicari :mobil
# barang di temukan
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: 6
# Masukkan Barang yang akan dicari indexnya: buku
# buku ada pada index ke-1
# 1. Menambah
# 2. Menghapus
# 3. Mengedit
# 4. Menampilkan
# 5. Memeriksa Barang
# 6. Mencari Index
# Masukkan Perintah: stop
# Program Berhenti. Selamat Tinggal
